# %%
#import libraries
import requests
from datetime import datetime as dt
from datetime import timedelta
import pandas as pd

# %%
# get events from n days ago
look_back_days = 45

days_ago_dte = dt.now() - timedelta(days=look_back_days)
print (days_ago_dte, type(days_ago_dte)) #gives us a time object
days_ago = days_ago_dte.strftime('%Y-%m-%d')
print (days_ago, type(days_ago)) #converts the time object to string so it can be based into the request

# you can limit the number of records that return from the API
# set to 0 for no limit
limit = 10

api_url = 'https://api.acleddata.com/acled/read?terms=accept&event_date={}&event_date_where=%3E=&limit={}'.format(days_ago, limit)
print (api_url, type(api_url)) #creates request according to ACLED format specifications - p. 13
# Out:
# 2020-07-28 05:32:54.597905 <class 'datetime.datetime'>
# 2020-07-28 <class 'str'>
# https://api.acleddata.com/acled/read?terms=accept&event_date=2020-07-28&event_date_where=%3E=&limit=10 <class 'str'>

# %%
response = requests.get(api_url) # Reality I spent 45 minutes figuring out why my search kept failing 
                                # and learned I had an older user guide that didn't include terms=accept 
data = response.json()
data.keys()
# Out:
# dict_keys(['status', 'success', 'last_update', 'count', 'messages', 'data', 'filename'])

# %%
data['status'], data['success'], data['count'] # see the refrenet for API status codes
# Out:
# (200, True, 10)

# %%
data_new = data['data'] #getting just the data 
rows = len(data_new)
print ('ACLED API returned {} rows'.format(rows))
# Out:
# ACLED API returned 10 rows

# %%
#convert it into an pandas data frame
acled_data = pd.DataFrame.from_dict(data_new)
acled_data
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty  event_date  year  \
# 0  7200414  508       MZM1723             1723  2020-09-05  2020
# 1  7200388  392       JPN3284             3284  2020-09-05  2020
# 2  7200387  392       JPN3289             3289  2020-09-05  2020
# 3  7200386  392       JPN3285             3285  2020-09-05  2020
# 4  7200257  356      IND79675            79675  2020-09-05  2020
# 5  7200252  356      IND79669            79669  2020-09-05  2020
# 6  7200236  356      IND79683            79683  2020-09-05  2020
# 7  7200091  356      IND79653            79653  2020-09-05  2020
# 8  7199467  586      PAK60866            60866  2020-09-05  2020
# 9  7199369  356      IND79679            79679  2020-09-05  2020
#
#   time_precision event_type    sub_event_type  \
# 0              1    Battles       Armed clash
# 1              1   Protests  Peaceful protest
# 2              1   Protests  Peaceful protest
# 3              1   Protests  Peaceful protest
# 4              1    Battles       Armed clash
# 5              1   Protests  Peaceful protest
# 6              1      Riots      Mob violence
# 7              2   Protests  Peaceful protest
# 8              1   Protests  Peaceful protest
# 9              1      Riots      Mob violence
#
#                              actor1  ...           location  latitude  \
# 0     Islamist Militia (Mozambique)  ...  Mocimboa Da Praia  -11.3460
# 1                Protesters (Japan)  ...           Ichikawa   35.7196
# 2                Protesters (Japan)  ...          Narashino   35.6823
# 3                Protesters (Japan)  ...     Tokyo-Shinjuku   35.7011
# 4  Unidentified Armed Group (India)  ...              Gurez   34.6364
# 5                Protesters (India)  ...         Puducherry   11.9338
# 6                   Rioters (India)  ...             Khowai   24.0670
# 7                Protesters (India)  ...          Ahmedabad   23.0257
# 8             Protesters (Pakistan)  ...            Karachi   24.9056
# 9                   Rioters (India)  ...           Chaygaon   26.0482
#
#   longitude geo_precision                            source  \
# 0   40.3522             2  Undisclosed Source; Nashir; Amaq
# 1  139.9294             1                     Sugito Action
# 2  140.0277             1                     Sugito Action
# 3  139.7090             1                     Sugito Action
# 4   74.7734             1              United News of India
# 5   79.8297             1              United News of India
# 6   91.6057             1                   Tripura Infoway
# 7   72.5872             1                    Times of India
# 8   67.0822             1                 Right Vision News
# 9   91.3867             1                     Pratidin Time
#
#           source_scale                                              notes  \
# 0  Local partner-Other  On 5 September 2020, an Islamist militia claim...
# 1            New media  On 5 September 2020, people protested at Moto-...
# 2            New media  On 5 September 2020, people held a standing pr...
# 3            New media  On 5 September 2020, 8 people protested at Shi...
# 4             National  On 5 September 2020, two dead bodies of HM mil...
# 5             National  On 5 September 2020, nearly 450 teachers held ...
# 6          Subnational  On 5 September 2020, a mob attacked and pelted...
# 7             National  Around 5 September 2020 (as reported), ABVP me...
# 8             National  On 5 September 2020, a protest was staged in K...
# 9          Subnational  On 5 September 2020, a group of five persons a...
#
#   fatalities   timestamp iso3
# 0         20  1599749473  MOZ
# 1          0  1599604517  JPN
# 2          0  1599604517  JPN
# 3          0  1599604517  JPN
# 4          2  1599602153  IND
# 5          0  1599602153  IND
# 6          0  1599602153  IND
# 7          0  1599602153  IND
# 8          0  1599602152  PAK
# 9          0  1599602151  IND
#
# [10 rows x 31 columns]

# %% [markdown]
# ### Does this comport with what is the in the documentation?
