# %%
#import libraries
import requests
from datetime import datetime as dt
from datetime import timedelta
import pandas as pd

# %%
# get events from n days ago
look_back_days = 45

days_ago_dte = dt.now() - timedelta(days=look_back_days)
print (days_ago_dte, type(days_ago_dte)) #gives us a time object
days_ago = days_ago_dte.strftime('%Y-%m-%d')
print (days_ago, type(days_ago)) #converts the time object to string so it can be based into the request

# you can limit the number of records that return from the API
# set to 0 for no limit
limit = 10

api_url = 'https://api.acleddata.com/acled/read?terms=accept&event_date={}&event_date_where=%3E=&limit={}'.format(days_ago, limit)
print (api_url, type(api_url)) #creates request according to ACLED format specifications - p. 13
# Out:
# 2020-08-06 12:19:11.626725 <class 'datetime.datetime'>
# 2020-08-06 <class 'str'>
# https://api.acleddata.com/acled/read?terms=accept&event_date=2020-08-06&event_date_where=%3E=&limit=10 <class 'str'>

# %%
response = requests.get(api_url) # Reality I spent 45 minutes figuring out why my search kept failing 
                                # and learned I had an older user guide that didn't include terms=accept 
data = response.json()
data.keys()
# Out:
# dict_keys(['status', 'success', 'last_update', 'count', 'messages', 'data', 'filename'])

# %%
data['status'], data['success'], data['count'] # see the refrenet for API status codes
# Out:
# (200, True, 10)

# %%
data_new = data['data'] #getting just the data 
rows = len(data_new)
print ('ACLED API returned {} rows'.format(rows))
# Out:
# ACLED API returned 10 rows

# %%
#convert it into an pandas data frame
acled_data = pd.DataFrame.from_dict(data_new)
acled_data
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty  event_date  year  \
# 0  7224030  499        MNE574              574  2020-09-12  2020
# 1  7224026  688       SRB1670             1670  2020-09-12  2020
# 2  7224016  300       GRC2190             2190  2020-09-12  2020
# 3  7224014  300       GRC2191             2191  2020-09-12  2020
# 4  7224013  300       GRC2195             2195  2020-09-12  2020
# 5  7224007  643       RUS5019             5019  2020-09-12  2020
# 6  7224000  804      UKR40481            40481  2020-09-12  2020
# 7  7223996  100       BGR1436             1436  2020-09-12  2020
# 8  7223990  643       RUS5016             5016  2020-09-12  2020
# 9  7223933  300       GRC2205             2205  2020-09-12  2020
#
#   time_precision event_type         sub_event_type                   actor1  \
# 0              1   Protests       Peaceful protest  Protesters (Montenegro)
# 1              1   Protests       Peaceful protest      Protesters (Serbia)
# 2              1      Riots           Mob violence         Rioters (Greece)
# 3              1   Protests       Peaceful protest      Protesters (Greece)
# 4              1      Riots  Violent demonstration  Rioters (International)
# 5              1   Protests       Peaceful protest      Protesters (Russia)
# 6              1   Protests       Peaceful protest     Protesters (Ukraine)
# 7              1   Protests       Peaceful protest    Protesters (Bulgaria)
# 8              1   Protests       Peaceful protest      Protesters (Russia)
# 9              1   Protests       Peaceful protest      Protesters (Greece)
#
#    ...               location latitude longitude geo_precision  \
# 0  ...                  Budva  42.3000   18.8414             1
# 1  ...    Belgrade-Stari Grad  44.8230   20.4605             1
# 2  ...              Orestiada  41.5060   26.5296             1
# 3  ...  Athens-Central Athens  37.9685   23.7585             1
# 4  ...               Mytilene  39.1100   26.5547             2
# 5  ...            Novosibirsk  55.0415   82.9346             1
# 6  ...           Monastyryska  49.0891   25.1733             1
# 7  ...                  Varna  43.2167   27.9167             1
# 8  ...               Ishimbay  53.4461   56.0357             1
# 9  ...                 Chania  35.5112   24.0292             1
#
#              source   source_scale  \
# 0           Vijesti       National
# 1  Vecernje Novosti       National
# 2           To Vima       National
# 3           To Vima       National
# 4           To Vima       National
# 5        Tayga.Info    Subnational
# 6          Segodnya       National
# 7              Sega       National
# 8            RFE/RL  International
# 9            I Avgi       National
#
#                                                notes fatalities   timestamp  \
# 0  On 12 September 2020, about 100 people protest...          0  1600197866
# 1  On 12 September 2020, supporters of the footba...          0  1600197866
# 2  On 12 September 2020, early in the morning, ri...          0  1600197865
# 3  On 12 September 2020, KEERFA organised a mass ...          0  1600197865
# 4  On 12 September 2020, on the fourth day since ...          0  1600197865
# 5  On 12 September 2020, about 15 people took par...          0  1600197865
# 6  On 12 September 2020, about 50 parents protest...          0  1600197865
# 7  On 12 September 2020, people protested in Varn...          0  1600197865
# 8  On 12 September 2020, at least 300 people took...          0  1600197865
# 9  On 12 September 2020, more than 5,000 demonstr...          0  1600197865
#
#   iso3
# 0  MNE
# 1  SRB
# 2  GRC
# 3  GRC
# 4  GRC
# 5  RUS
# 6  UKR
# 7  BGR
# 8  RUS
# 9  GRC
#
# [10 rows x 31 columns]

# %% [markdown]
# ### Does this comport with what is the in the documentation?
