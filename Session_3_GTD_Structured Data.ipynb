# %% [markdown]
# # Dealing with Structured Data- Global Terrorism Database

# %% [markdown]
# ### Thanks to Samuel Capps (6980 2020 QTR 1) for identifying this dynamic

# %%
# Import libraries to aid your analysis
import pandas as pd #pandas places ones data in tables format
from bokeh.plotting import figure, output_notebook, show #builds interactive graphs for python
from bokeh.models import Range1d
import math #this is used in graphic section to use the irrational number pi
output_notebook() #Allows inline plotting for Juptyer notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Let's look at the data

# %%
# Datasheet was downbloaed form GTD and being read in form a local .csv file
GTD = pd.read_csv(r"D:\06-CogDev\04-Institutions\NIU\2020\Data-Applications\Week3\globalterrorismdb_0919dist.csv",
                  encoding = "ISO-8859-1", engine = 'python') 
# had some issues with the data types, had to search online for example to read properly
GTD.head() # see the structure--default is first five rows
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
# Pandas library has a describe function to apply algorithms against the data...
# whether approriate or not
GTD.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.914640e+05  191464.000000  191464.000000  191464.000000
# mean   2.003486e+11    2003.420136       6.462510      15.507688
# std    1.334949e+09      13.349405       3.388515       8.807727
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991083e+11    1991.000000       4.000000       8.000000
# 50%    2.010031e+11    2010.000000       6.000000      15.000000
# 75%    2.015013e+11    2015.000000       9.000000      23.000000
# max    2.018123e+11    2018.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  191464.000000  191464.000000  191464.000000  186884.000000
# mean        0.047476     131.290446       7.205167      23.462121
# std         0.212656     112.058063       2.923811      18.405309
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       6.000000      11.274796
# 50%         0.000000      98.000000       7.000000      31.445840
# 75%         0.000000     160.000000      10.000000      34.621521
# max         1.000000    1004.000000      12.000000      74.633553
#
#            longitude    specificity  ...     ransomamt   ransomamtus  \
# count  186883.000000  191463.000000  ...  1.416000e+03  6.230000e+02
# mean       28.902126       1.458172  ...  3.057619e+06  5.227734e+05
# std        57.231040       0.991536  ...  2.951278e+07  6.730057e+06
# min      -176.176447       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%         7.052742       1.000000  ...  0.000000e+00  0.000000e+00
# 50%        43.471427       1.000000  ...  1.500000e+04  0.000000e+00
# 75%        68.783077       1.000000  ...  4.000000e+05  0.000000e+00
# max       179.366667       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  8.380000e+02    611.000000    12045.000000  11454.000000
# mean   6.961705e+05    217.004910        4.643005    -29.816309
# std    9.792528e+06   2796.042504        2.034429     65.183303
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2912.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  191464.000000  191464.000000  191464.000000  191464.000000
# mean       -4.521727      -4.439247       0.088951      -3.930582
# std         4.543713       4.639931       0.556741       4.689726
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
#Identifies the total number of rows
len(GTD)
# Out:
# 191464

# %%
#provides information about the dataframe
GTD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191464 entries, 0 to 191463
# Columns: 135 entries, eventid to related
# dtypes: float64(53), int64(24), object(58)
# memory usage: 197.2+ MB

# %%
#See the titles of the 135 columns
for col in GTD.columns:
    print(col)
# !!!! Look in the GTD_Codebook to get more information about each column !!!!
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %% [markdown]
# # Problem 1: Change the Country (do after going through the whole notebook)

# %%
# reduce the dataframe down to just the philippines
country = GTD[GTD["country_txt"]=="Peru"] # store the information in an object called country
#you can change Philippines to any country in the dataset
country.head(10) #by putting in 10 I changed the default setting of 1st 5 rows to 1st 10 rows
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 1941  197307040002   1973       7     4        NaN         0        NaN
# 1960  197307220001   1973       7    22        NaN         0        NaN
# 1961  197307220002   1973       7    22        NaN         0        NaN
# 2561  197409190002   1974       9    19        NaN         0        NaN
# 2671  197411210001   1974      11    21        NaN         0        NaN
# 2700  197412070002   1974      12     7        NaN         0        NaN
# 2946  197504090001   1975       4     9        NaN         0        NaN
# 3072  197506080001   1975       6     8        NaN         0        NaN
# 4544  197702220002   1977       2    22        NaN         0        NaN
# 4916  197706180002   1977       6    18        NaN         0        NaN
#
#       country country_txt  region  ... addnotes scite1 scite2  scite3  \
# 1941      159        Peru       3  ...      NaN    NaN    NaN     NaN
# 1960      159        Peru       3  ...      NaN    NaN    NaN     NaN
# 1961      159        Peru       3  ...      NaN    NaN    NaN     NaN
# 2561      159        Peru       3  ...      NaN    NaN    NaN     NaN
# 2671      159        Peru       3  ...      NaN    NaN    NaN     NaN
# 2700      159        Peru       3  ...      NaN    NaN    NaN     NaN
# 2946      159        Peru       3  ...      NaN    NaN    NaN     NaN
# 3072      159        Peru       3  ...      NaN    NaN    NaN     NaN
# 4544      159        Peru       3  ...      NaN    NaN    NaN     NaN
# 4916      159        Peru       3  ...      NaN    NaN    NaN     NaN
#
#       dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 1941      PGIS       -9        -9        1       1      NaN
# 1960      PGIS       -9        -9        0      -9      NaN
# 1961      PGIS       -9        -9        1       1      NaN
# 2561      PGIS       -9        -9        1       1      NaN
# 2671      PGIS        0         1        1       1      NaN
# 2700      PGIS       -9        -9        1       1      NaN
# 2946      PGIS        0         0        0       0      NaN
# 3072      PGIS        0         1        1       1      NaN
# 4544      PGIS       -9        -9        1       1      NaN
# 4916      PGIS       -9        -9        0      -9      NaN
#
# [10 rows x 135 columns]

# %% [markdown]
# ### Let's deep dive in a country

# %%
attacks_by_group = {} #make an empty datastructure (dictionary) to fill

#This loop goes through each row and counts the number of entries by group
for index, row in country.iterrows(): 
    if row["gname"]  in attacks_by_group.keys():
        attacks_by_group[row["gname"]] += 1 #if group is in the dictionary add 1 attack
    else:
        attacks_by_group[row["gname"]] = 1 #add group name to dictionary if not in dictionary

attacks_by_group
# Out:
# {'Unknown': 899,
#  'Condor': 1,
#  'Revolutionary Vanguard': 2,
#  'Movement of the Revolutionary Left (MIR) (Peru)': 7,
#  'Coordination of the United Revolutionary Organization (CORU)': 1,
#  'Shining Path (SL)': 4548,
#  'Peruvian Anti-Communist Alliance (AAP)': 1,
#  'Politico-Military Revolutionary Command': 1,
#  'Strikers': 1,
#  'Left-Wing Terrorists': 1,
#  'Commandos': 1,
#  'Sunni Muslim extremists': 1,
#  'M-19 (Movement of April 19)': 1,
#  'Youths': 1,
#  'Guerrilla Army of the Poor (EGP)': 1,
#  'Tupac Amaru Revolutionary Movement (MRTA)': 552,
#  'Armed People': 1,
#  'Narco-Terrorists': 14,
#  'Guerrillas': 3,
#  'Maoists': 4,
#  'Javier Heraud Revolutionary Commando': 1,
#  "People's Revolutionary Command (CRP)": 5,
#  'Drug-Related Terrorists': 1,
#  'Peruvian Rebels': 1,
#  'Terrorists': 11,
#  'Subversives': 1,
#  'Death Squad': 6,
#  'Manuel Rodriguez Patriotic Front (FPMR)': 1,
#  'Rodrigo Franco Command': 15,
#  'East Timorese extremists': 1,
#  'National Liberation Army (Peru)': 2,
#  'Struggle Against Misery and Exploitation of Peasants': 2,
#  'Patriotic Liberation Front': 5,
#  'Right-Wing Group': 1,
#  "People's Guerrilla Front": 1,
#  'Revolutionary Armed Forces of Colombia (FARC)': 4,
#  'Anti-Nuclear extremists': 1,
#  'Rebels': 1,
#  'Ticuna Indian': 1,
#  'Rebel Military Unit': 1,
#  'Etnocacerista Movement': 1,
#  'Wampis extremists': 3,
#  'Militarized Communist Party of Peru (MPCP)': 1}

# %%
# Make X and Y axis for a bar chart plotting attacks
groups = list(attacks_by_group.keys())
attacks = list(attacks_by_group.values())

# %%
#Sort from largest to smallest
sorted_groups = sorted(groups, key=lambda x: attacks[groups.index(x)], reverse=True)
sorted_attacks = sorted(attacks, reverse=True)

sorted_groups1=sorted_groups[0:5]
sorted_attacks1=sorted_attacks[0:5]
    
print(sorted_groups1)
print(sorted_attacks1)
# Out:
# ['Shining Path (SL)', 'Unknown', 'Tupac Amaru Revolutionary Movement (MRTA)', 'Rodrigo Franco Command', 'Narco-Terrorists']
# [4548, 899, 552, 15, 14]

# %% [markdown]
# # Problem 2: For any country only do plot the top 5 groups (Hint: Use list slicing e.g sorted_attacks[-10:])

# %%
# Uses the bokeh library to plot an interactive graph ---this is very basic view of its capability
# makes the figure
p = figure(x_range = sorted_attacks1, plot_width=800, plot_height=1200)
#Plots the data
p.vbar(x=sorted_groups1, width=0.5, bottom=0,
       top= sorted_attacks1, color="firebrick")

p.xaxis.major_label_orientation = math.pi/2  #Rotates the labels on the X axis
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-920ec1242923> in <module>
#       1 # Uses the bokeh library to plot an interactive graph ---this is very basic view of its capability
#       2 # makes the figure
# ----> 3 p = figure(x_range = sorted_attacks1, plot_width=800, plot_height=1200)
#       4 #Plots the data
#       5 p.vbar(x=sorted_groups1, width=0.5, bottom=0,
#
# ~\anaconda3\lib\site-packages\bokeh\plotting\figure.py in figure(**kwargs)
#    1530
#    1531 def figure(**kwargs):
# -> 1532     return Figure(**kwargs)
#    1533 figure.__doc__ = Figure.__doc__
#    1534
#
# ~\anaconda3\lib\site-packages\bokeh\plotting\figure.py in __init__(self, *arg, **kw)
#     165         super().__init__(*arg, **kw)
#     166
# --> 167         self.x_range = get_range(opts.x_range)
#     168         self.y_range = get_range(opts.y_range)
#     169
#
# ~\anaconda3\lib\site-packages\bokeh\plotting\_plot.py in get_range(range_input)
#      79             except ValueError:  # @mattpap suggests ValidationError instead
#      80                 pass
# ---> 81     raise ValueError("Unrecognized range input: '%s'" % str(range_input))
#      82
#      83 def get_scale(range_input, axis_type):
#
# ValueError: Unrecognized range input: '[4548, 899, 552, 15, 14]'

# %%
show(p)
# Out:
#   <div class="bk-root" id="d0aeabbe-4c4d-445a-9e07-d501d6d43cbc" data-root-id="1276"></div>

# %% [markdown]
# ## Now lets plot the attacks in a map

# %%
#Imports necessary aspects of Bokeh for plotting on a map
# !pip install pyproj
from bokeh.tile_providers import get_provider, Vendors
from pyproj import Transformer
tile_provider = get_provider('STAMEN_TERRAIN')
# Out:
# Requirement already satisfied: pyproj in c:\users\samuel\anaconda3\lib\site-packages (2.6.1.post1)

# %%
# Take the data reduced to a country and get the lat/long of the attacks and the name of the group
country_map = country[["latitude", 'longitude', 'gname']]

#see the data this time first 7 rows
country_map.head(7)
# Out:
#        latitude  longitude                   gname
# 1941 -11.967368 -76.978462                 Unknown
# 1960 -11.967368 -76.978462                 Unknown
# 1961 -11.967368 -76.978462                 Unknown
# 2561 -16.409501 -71.537384                  Condor
# 2671 -11.967368 -76.978462  Revolutionary Vanguard
# 2700 -11.967368 -76.978462                 Unknown
# 2946 -11.967368 -76.978462  Revolutionary Vanguard

# %%
#create pyproj transformer to convert form lat/long to web mercator
transformer = Transformer.from_crs('epsg:4326','epsg:3857')

# %%
map_dict = {} # empty dictionary to track group attacks by lat long
nan_count = {} # some data doesn't have a lat/long so we need to know what we are losing


# Iterate through tables and associate group with lat/long
for idx, row in country_map.iterrows():    
    if row['gname'] in map_dict.keys(): 
        if math.isnan(row["latitude"]):
            #This counts no data
            if row['gname'] in nan_count.keys(): 
                nan_count[row['gname']] += 1 
            else: 
                nan_count[row['gname']] = 1
        else: 
            #This has to convert the lat/long to a mercator projection 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['gname']].append([point[0],point[1]]) 
    #BOTH the if an else statement do the same thing but since it is a dictionary one needs to add the group name first
    else:  
        if math.isnan(row["latitude"]):
          nan_count[row['gname']] = 1
        else: 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['gname']] =[[point[0],point[1]]]
    
        
#This tells how many attacks we are losing
nan_count
# Out:
# {'Coordination of the United Revolutionary Organization (CORU)': 1,
#  'Shining Path (SL)': 247,
#  'Unknown': 28,
#  'Youths': 1,
#  'Narco-Terrorists': 1,
#  'Tupac Amaru Revolutionary Movement (MRTA)': 7,
#  'Terrorists': 1,
#  'Death Squad': 1,
#  'Wampis extremists': 1}

# %% [markdown]
# # Problem 3: Print the top 5 groups from the map_dict structure

# %%
length_dict = {key: len(value) for key, value in map_dict.items()}

list_dict = [(k, v) for k, v in length_dict.items()]
list_dict.sort(key=lambda x: x[1], reverse=True)
for a in list_dict[0:5]:
    for items in a:
        print(items)
# Out:
# Shining Path (SL)
# 4301
# Unknown
# 871
# Tupac Amaru Revolutionary Movement (MRTA)
# 545
# Rodrigo Franco Command
# 15
# Narco-Terrorists
# 12

# %% [markdown]
# # Problem 4: Change the map to show a new country.
# ## You can get the lat/long for different places here : https://www.latlong.net/

# %%
pts = [(0,-85), (-20,-65)]
bbox = []
for pt in transformer.itransform(pts): 
    bbox.append(pt)

# %%
NPA_x = []
NPA_y = []
for pt in map_dict["Shining Path (SL)"]:
    NPA_x.append(pt[0])
    NPA_y.append(pt[1])

# %%
#Plots the bounding box
p = figure(x_range=(bbox[0][0], bbox[1][0]),y_range=(bbox[0][1], bbox[1][1]),x_axis_type="mercator", y_axis_type="mercator")
#add the map form the Bokeh map vendor in this case Stamen_Terrain --- see documentation
p.add_tile(tile_provider)
# Places a circle for each converted lat/long attack 
p.circle(x = NPA_x, y = NPA_y, color= "firebrick")

#shows the plot
show(p)
# Out:
#   <div class="bk-root" id="24c1af04-c9c5-41b2-9a46-73c416758da4" data-root-id="1514"></div>
